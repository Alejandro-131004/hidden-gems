# %% [markdown]
# # Visualising Information

# %%
import pandas as pd

# %% [markdown]
# ```py
#
# df = pd.read_excel("../data/sample500_bundesliga2.xlsx")
#
# df.to_csv("../data/sample500_bundesliga2.csv", index=False)
#
# ```

# %%
df = pd.read_csv("../data/sample500_bundesliga2.csv")
df.head()
# Out:
#         Player            Team Team within selected timeframe  Position  Age  \
# 0  M. Svanberg       Wolfsburg                      Wolfsburg       AMF   27
# 1   Vini Souza       Wolfsburg                      Wolfsburg      LDMF   27
# 2   M. Berisha  Kaiserslautern                 Kaiserslautern        CF   28
# 3  M. Ljubičić    Union Berlin                   Union Berlin  CF, LAMF   24
# 4    M. Arnold       Wolfsburg                      Wolfsburg      LDMF   32
#
#    Market value Contract expires  Matches played  Minutes played  Goals  ...  \
# 0      12000000       2027-06-30               1               5      0  ...
# 1      12000000       2030-06-30               1              85      0  ...
# 2      10000000       2027-06-30              12             765      2  ...
# 3       8000000              NaN              10             696      0  ...
# 4       7000000       2028-06-30               1              13      0  ...
#
# ...

# %%
ls_columns = list(df.columns)
for i in range(len(ls_columns)):
    print(f"{i}: {ls_columns[i]}")
# Out:
# 0: Player
# 1: Team
# 2: Team within selected timeframe
# 3: Position
# 4: Age
# 5: Market value
# 6: Contract expires
# 7: Matches played
# 8: Minutes played
# 9: Goals
# 10: xG
# 11: Assists
# 12: xA
# 13: Duels per 90
# 14: Duels won, %
# 15: Birth country
# 16: Passport country
# 17: Foot
# 18: Height
# 19: Weight
# 20: On loan
# 21: Successful defensive actions per 90
# 22: Defensive duels per 90
# 23: Defensive duels won, %
# 24: Aerial duels per 90
# 25: Aerial duels won, %
# 26: Sliding tackles per 90
# 27: PAdj Sliding tackles
# 28: Shots blocked per 90
# 29: Interceptions per 90
# 30: PAdj Interceptions
# 31: Fouls per 90
# 32: Yellow cards
# 33: Yellow cards per 90
# 34: Red cards
# 35: Red cards per 90
# 36: Successful attacking actions per 90
# 37: Goals per 90
# 38: Non-penalty goals
# 39: Non-penalty goals per 90
# 40: xG per 90
# 41: Head goals
# 42: Head goals per 90
# 43: Shots
# 44: Shots per 90
# 45: Shots on target, %
# 46: Goal conversion, %
# ...
